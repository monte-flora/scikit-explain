# %% [markdown]
# # Exploring Variance Inflation Factor

# %%
import sys, os 
current_dir = os.getcwd()
path = os.path.dirname(current_dir)
sys.path.append(path)

# %%
import mintpy
import plotting_config
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading the training data and pre-fit models

# %%
model_objs, model_names = mintpy.load_models()
examples, targets = mintpy.load_data()
# Out:
#    dllwave_flux  dwpt2m  fric_vel  gflux  high_cloud  lat_hf  low_cloud  \
# 0         211.0  -2.504      0.28   44.0         0.0   -10.0      8.875
# 1         241.2  -4.168      0.36  -10.0         0.0    70.0     13.125
# 2         242.0  -2.172      0.31   43.0         0.0    25.0      0.000
# 3         220.4  -3.291      0.62   75.0         0.0    30.0      0.000
# 4         212.9  -5.020      0.15   50.0         0.0     0.0      0.000
#
#    mid_cloud  sat_irbt  sens_hf  ...  vdd_flux  wind10m  date_marker  urban  \
# 0        0.0     -9.50    -21.0  ...     8.875    3.654         48.0    0.0
# 1        0.0     -3.00     85.0  ...    13.125    2.324         31.0    1.0
# 2        0.0     -0.75    -50.0  ...     0.000    4.110         19.0    0.0
# 3        0.0     -3.00    -30.0  ...     0.000    3.480         50.0    1.0
# 4        0.0     -7.25    -20.0  ...     0.000    3.438         16.0    0.0
#
#    rural  d_ground  d_rad_d  d_rad_u  hrrr_dT  target
# 0    1.0      65.0   -211.0   -302.8   0.9624     0.0
# 1    0.0     -95.0    358.8    293.8  -2.7770     0.0
# 2    1.0      93.0   -242.0   -316.5   1.6900     0.0
# 3    0.0     105.0   -220.4   -313.5   0.9844     0.0
# 4    1.0      70.0   -212.9   -274.8   1.9300     1.0
#
# [5 rows x 31 columns]
